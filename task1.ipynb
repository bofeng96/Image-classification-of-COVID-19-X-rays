# %% [markdown]
# # Class Challenge: Image Classification of COVID-19 X-rays
# # Task 1 [Total points: 30]

# %% [markdown]
# ## Setup
#
# * This assignment involves the following packages: 'matplotlib', 'numpy', and 'sklearn'.
#
# * If you are using conda, use the following commands to install the above packages:<br>
# ```shell
# conda install matplotlib
# conda install numpy
# conda install -c anaconda scikit-learn
# ```
#
# * If you are using pip, use use the following commands to install the above packages: <br>
# ```shell
# pip install matplotlib
# pip install numpy
# pip install sklearn
# ```

# %% [markdown]
# ## Data
#
# Please download the data using the following link: [COVID-19](https://drive.google.com/file/d/1Y88tgqpQ1Pjko_7rntcPowOJs_QNOrJ-/view).
#
# * After downloading 'Covid_Data_GradientCrescent.zip', unzip the file and you should see the following data structure:
#
#
# |--all<br>
# |--------train<br>
# |--------test<br>
# |--two<br>
# |--------train<br>
# |--------test<br>
#
#
# * Put the 'all' folder, the 'two' folder and this python notebook in the **same directory** so that the following code can correctly locate the data.

# %% [markdown]
# ## [20 points] Binary Classification: COVID-19 vs. Normal

# %%
import os

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator

os.environ['OMP_NUM_THREADS'] = '8'
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
tf.__version__
# Out:
# '2.1.0'

# %% [markdown]
# #### Load Image Data

# %%
DATA_LIST = os.listdir('two/train')
DATASET_PATH  = 'two/train'
TEST_DIR =  'two/test'
IMAGE_SIZE    = (224, 224)
NUM_CLASSES   = len(DATA_LIST)
BATCH_SIZE    = 10  # try reducing batch size or freeze more layers if your GPU runs out of memory
NUM_EPOCHS    = 40
LEARNING_RATE = 0.0005 # start off with high rate first 0.001 and experiment with reducing it gradually

# %% [markdown]
# #### Generate Training and Validation Batches

# %%
train_datagen = ImageDataGenerator(rescale=1./255,rotation_range=50,featurewise_center = True,
                                   featurewise_std_normalization = True,width_shift_range=0.2,
                                   height_shift_range=0.2,shear_range=0.25,zoom_range=0.1,
                                   zca_whitening = True,channel_shift_range = 20,
                                   horizontal_flip = True,vertical_flip = True,
                                   validation_split = 0.2,fill_mode='constant')

train_batches = train_datagen.flow_from_directory(DATASET_PATH,target_size=IMAGE_SIZE,
                                                  shuffle=True,batch_size=BATCH_SIZE,
                                                  subset = "training",seed=42,
                                                  class_mode="binary")

valid_batches = train_datagen.flow_from_directory(DATASET_PATH,target_size=IMAGE_SIZE,
                                                  shuffle=True,batch_size=BATCH_SIZE,
                                                  subset = "validation",seed=42,
                                                  class_mode="binary")
# Out:
# /share/pkg.7/tensorflow/2.1.0/install/lib/SCC/../python3.6-gpu/site-packages/keras_preprocessing/image/image_data_generator.py:341: UserWarning: This ImageDataGenerator specifies `zca_whitening` which overrides setting of`featurewise_std_normalization`.
#   warnings.warn('This ImageDataGenerator specifies '
# Found 104 images belonging to 2 classes.
# Found 26 images belonging to 2 classes.

# %% [markdown]
# #### [10 points] Build Model
# Hint: Starting from a pre-trained model typically helps performance on a new task, e.g. starting with weights obtained by training on ImageNet.

# %%
#raise NotImplementedError("Build your model based on an architecture of your choice "
#                          "A sample model summary is shown below")

model = tf.keras.Sequential()
pre_trained = tf.keras.applications.VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
pre_trained.trainable = False
model.add(pre_trained)
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dropout(0.25))
model.add(tf.keras.layers.Dense(256, activation='relu', name="dense_feature"))
model.add(tf.keras.layers.Dropout(0.25))
model.add(tf.keras.layers.Dense(1, activation='sigmoid', name="dense_1"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 7, 7, 512)         14714688
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 25088)             0
# _________________________________________________________________
# dense_feature (Dense)        (None, 256)               6422784
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 21,137,729
# Trainable params: 6,423,041
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# #### [5 points] Train Model

# %%
#FIT MODEL
print(len(train_batches))
print(len(valid_batches))

STEP_SIZE_TRAIN=train_batches.n//train_batches.batch_size
STEP_SIZE_VALID=valid_batches.n//valid_batches.batch_size

# raise NotImplementedError("Use the model.fit function to train your network")
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

history = model.fit(train_batches, steps_per_epoch=STEP_SIZE_TRAIN, epochs=40, 
                    validation_data=valid_batches, validation_steps=STEP_SIZE_VALID)
# Out:
# 11
# 3
# /share/pkg.7/tensorflow/2.1.0/install/lib/SCC/../python3.6-gpu/site-packages/keras_preprocessing/image/image_data_generator.py:716: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /share/pkg.7/tensorflow/2.1.0/install/lib/SCC/../python3.6-gpu/site-packages/keras_preprocessing/image/image_data_generator.py:735: UserWarning: This ImageDataGenerator specifies `zca_whitening`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 10 steps, validate for 2 steps
# Epoch 1/40
# /share/pkg.7/tensorflow/2.1.0/install/lib/SCC/../python3.6-gpu/site-packages/keras_preprocessing/image/image_data_generator.py:716: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /share/pkg.7/tensorflow/2.1.0/install/lib/SCC/../python3.6-gpu/site-packages/keras_preprocessing/image/image_data_generator.py:735: UserWarning: This ImageDataGenerator specifies `zca_whitening`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# 10/10 [==============================] - 4s 419ms/step - loss: 2.1177 - accuracy: 0.5200 - val_loss: 1.2182 - val_accuracy: 0.6000
# Epoch 2/40
# 10/10 [==============================] - 4s 364ms/step - loss: 0.9871 - accuracy: 0.6915 - val_loss: 0.2770 - val_accuracy: 0.9500
# Epoch 3/40
# 10/10 [==============================] - 3s 316ms/step - loss: 0.5167 - accuracy: 0.8191 - val_loss: 0.2626 - val_accuracy: 0.9500
# Epoch 4/40
# 10/10 [==============================] - 3s 338ms/step - loss: 0.6449 - accuracy: 0.7340 - val_loss: 0.0369 - val_accuracy: 1.0000
# Epoch 5/40
# 10/10 [==============================] - 3s 321ms/step - loss: 0.5792 - accuracy: 0.8085 - val_loss: 0.3043 - val_accuracy: 0.9000
# Epoch 6/40
# 10/10 [==============================] - 3s 332ms/step - loss: 0.2887 - accuracy: 0.9149 - val_loss: 0.0576 - val_accuracy: 1.0000
# Epoch 7/40
# 10/10 [==============================] - 3s 336ms/step - loss: 0.2515 - accuracy: 0.9149 - val_loss: 0.0878 - val_accuracy: 0.9500
# Epoch 8/40
# 10/10 [==============================] - 3s 323ms/step - loss: 0.1827 - accuracy: 0.9362 - val_loss: 0.0839 - val_accuracy: 1.0000
# Epoch 9/40
# 10/10 [==============================] - 3s 339ms/step - loss: 0.1895 - accuracy: 0.9362 - val_loss: 0.0374 - val_accuracy: 1.0000
# Epoch 10/40
# 10/10 [==============================] - 3s 329ms/step - loss: 0.1690 - accuracy: 0.8936 - val_loss: 0.0738 - val_accuracy: 0.9500
# Epoch 11/40
# 10/10 [==============================] - 3s 333ms/step - loss: 0.1780 - accuracy: 0.9468 - val_loss: 0.0369 - val_accuracy: 1.0000
# Epoch 12/40
# 10/10 [==============================] - 3s 325ms/step - loss: 0.2054 - accuracy: 0.9149 - val_loss: 0.1791 - val_accuracy: 0.9500
# Epoch 13/40
# 10/10 [==============================] - 3s 319ms/step - loss: 0.1456 - accuracy: 0.9362 - val_loss: 0.0334 - val_accuracy: 1.0000
# Epoch 14/40
# 10/10 [==============================] - 3s 324ms/step - loss: 0.1553 - accuracy: 0.9574 - val_loss: 0.2396 - val_accuracy: 0.9500
# Epoch 15/40
# 10/10 [==============================] - 3s 322ms/step - loss: 0.1146 - accuracy: 0.9681 - val_loss: 0.0559 - val_accuracy: 1.0000
# Epoch 16/40
# 10/10 [==============================] - 3s 325ms/step - loss: 0.1648 - accuracy: 0.9468 - val_loss: 0.1264 - val_accuracy: 0.9500
# Epoch 17/40
# 10/10 [==============================] - 3s 327ms/step - loss: 0.2196 - accuracy: 0.8936 - val_loss: 0.1722 - val_accuracy: 0.9000
# Epoch 18/40
# 10/10 [==============================] - 3s 334ms/step - loss: 0.1622 - accuracy: 0.8723 - val_loss: 0.0259 - val_accuracy: 1.0000
# Epoch 19/40
# 10/10 [==============================] - 3s 327ms/step - loss: 0.1632 - accuracy: 0.9362 - val_loss: 0.0400 - val_accuracy: 1.0000
# Epoch 20/40
# 10/10 [==============================] - 3s 319ms/step - loss: 0.0770 - accuracy: 0.9681 - val_loss: 0.1959 - val_accuracy: 0.9000
# Epoch 21/40
# 10/10 [==============================] - 3s 314ms/step - loss: 0.2670 - accuracy: 0.8723 - val_loss: 0.0862 - val_accuracy: 0.9500
# Epoch 22/40
# 10/10 [==============================] - 4s 351ms/step - loss: 0.1271 - accuracy: 0.9600 - val_loss: 0.1014 - val_accuracy: 0.9500
# Epoch 23/40
# 10/10 [==============================] - 3s 338ms/step - loss: 0.1289 - accuracy: 0.9255 - val_loss: 0.0563 - val_accuracy: 1.0000
# Epoch 24/40
# 10/10 [==============================] - 3s 334ms/step - loss: 0.1142 - accuracy: 0.9468 - val_loss: 0.1036 - val_accuracy: 0.9500
# Epoch 25/40
# 10/10 [==============================] - 3s 331ms/step - loss: 0.1565 - accuracy: 0.9255 - val_loss: 0.4086 - val_accuracy: 0.8500
# Epoch 26/40
# 10/10 [==============================] - 3s 332ms/step - loss: 0.0754 - accuracy: 0.9681 - val_loss: 0.0269 - val_accuracy: 1.0000
# Epoch 27/40
# 10/10 [==============================] - 3s 322ms/step - loss: 0.2236 - accuracy: 0.9574 - val_loss: 0.2478 - val_accuracy: 0.8500
# Epoch 28/40
# 10/10 [==============================] - 3s 322ms/step - loss: 0.3026 - accuracy: 0.9043 - val_loss: 0.0374 - val_accuracy: 1.0000
# Epoch 29/40
# 10/10 [==============================] - 4s 355ms/step - loss: 0.2452 - accuracy: 0.8800 - val_loss: 0.0385 - val_accuracy: 1.0000
# Epoch 30/40
# 10/10 [==============================] - 3s 334ms/step - loss: 0.1921 - accuracy: 0.9255 - val_loss: 0.1804 - val_accuracy: 0.9500
# Epoch 31/40
# 10/10 [==============================] - 3s 330ms/step - loss: 0.1667 - accuracy: 0.9362 - val_loss: 0.0588 - val_accuracy: 1.0000
# Epoch 32/40
# 10/10 [==============================] - 3s 323ms/step - loss: 0.1248 - accuracy: 0.9468 - val_loss: 0.1288 - val_accuracy: 0.9000
# Epoch 33/40
# 10/10 [==============================] - 3s 329ms/step - loss: 0.0932 - accuracy: 0.9574 - val_loss: 0.0200 - val_accuracy: 1.0000
# Epoch 34/40
# 10/10 [==============================] - 3s 320ms/step - loss: 0.1492 - accuracy: 0.9362 - val_loss: 0.0190 - val_accuracy: 1.0000
# Epoch 35/40
# 10/10 [==============================] - 3s 337ms/step - loss: 0.1451 - accuracy: 0.9362 - val_loss: 0.0303 - val_accuracy: 1.0000
# Epoch 36/40
# 10/10 [==============================] - 3s 317ms/step - loss: 0.0822 - accuracy: 0.9574 - val_loss: 0.0286 - val_accuracy: 1.0000
# Epoch 37/40
# 10/10 [==============================] - 4s 351ms/step - loss: 0.1878 - accuracy: 0.9300 - val_loss: 0.0847 - val_accuracy: 0.9500
# Epoch 38/40
# 10/10 [==============================] - 3s 335ms/step - loss: 0.1481 - accuracy: 0.9468 - val_loss: 0.1262 - val_accuracy: 0.9500
# Epoch 39/40
# 10/10 [==============================] - 3s 333ms/step - loss: 0.1526 - accuracy: 0.9468 - val_loss: 0.0165 - val_accuracy: 1.0000
# Epoch 40/40
# 10/10 [==============================] - 3s 343ms/step - loss: 0.1357 - accuracy: 0.9500 - val_loss: 0.0739 - val_accuracy: 1.0000

# %% [markdown]
# #### [5 points] Plot Accuracy and Loss During Training

# %%
import matplotlib.pyplot as plt

# raise NotImplementedError("Plot the accuracy and the loss during training")
plt.figure(figsize=(15, 5)) 
plt.subplot(121)
plt.plot(history.history['accuracy'], label='Train_acc')
plt.plot(history.history['val_accuracy'], label='Test_acc')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy over 40 Epochs')
plt.legend(loc='lower right')
plt.grid()

plt.subplot(122)
plt.plot(history.history['loss'], label='Train_loss')
plt.plot(history.history['val_loss'], label='Test_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0, 1])
plt.title('Loss over 40 Epochs')
plt.legend(loc='upper right')
plt.grid()

# %% [markdown]
# #### Plot Test Results

# %%
import matplotlib.image as mpimg

test_datagen = ImageDataGenerator(rescale=1. / 255)
eval_generator = test_datagen.flow_from_directory(TEST_DIR,target_size=IMAGE_SIZE,
                                                  batch_size=1,shuffle=True,seed=42,class_mode="binary")
eval_generator.reset()
pred = model.predict_generator(eval_generator,18,verbose=1)
for index, probability in enumerate(pred):
    image_path = TEST_DIR + "/" +eval_generator.filenames[index]
    image = mpimg.imread(image_path)
    if image.ndim < 3:
        image = np.reshape(image,(image.shape[0],image.shape[1],1))
        image = np.concatenate([image, image, image], 2)
#         print(image.shape)

    pixels = np.array(image)
    plt.imshow(pixels)
    
    print(eval_generator.filenames[index])
    if probability > 0.5:
        plt.title("%.2f" % (probability[0]*100) + "% Normal")
    else:
        plt.title("%.2f" % ((1-probability[0])*100) + "% COVID19 Pneumonia")
    plt.show()
# Out:
# Found 18 images belonging to 2 classes.
# WARNING:tensorflow:From <ipython-input-7-543347a5fba8>:7: Model.predict_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.predict, which supports generators.
# 18/18 [==============================] - 1s 50ms/step
# covid/nejmoa2001191_f3-PA.jpeg
# covid/nejmoa2001191_f4.jpeg
# covid/nejmoa2001191_f5-PA.jpeg
# covid/radiol.2020200490.fig3.jpeg
# covid/ryct.2020200028.fig1a.jpeg
# covid/ryct.2020200034.fig2.jpeg
# covid/ryct.2020200034.fig5-day0.jpeg
# covid/ryct.2020200034.fig5-day4.jpeg
# covid/ryct.2020200034.fig5-day7.jpeg
# normal/NORMAL2-IM-1385-0001.jpeg
# normal/NORMAL2-IM-1396-0001.jpeg
# normal/NORMAL2-IM-1400-0001.jpeg
# normal/NORMAL2-IM-1401-0001.jpeg
# normal/NORMAL2-IM-1406-0001.jpeg
# normal/NORMAL2-IM-1412-0001.jpeg
# normal/NORMAL2-IM-1419-0001.jpeg
# normal/NORMAL2-IM-1422-0001.jpeg
# normal/NORMAL2-IM-1423-0001.jpeg

# %% [markdown]
# ## [10 points] TSNE Plot
# t-Distributed Stochastic Neighbor Embedding (t-SNE) is a widely used technique for dimensionality reduction that is particularly well suited for the visualization of high-dimensional datasets. After training is complete, extract features from a specific deep layer of your choice, use t-SNE to reduce the dimensionality of your extracted features to 2 dimensions and plot the resulting 2D features.

# %%
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import tensorflow.keras.models as models
import seaborn as sns

intermediate_layer_model = models.Model(inputs=model.input,
                                        outputs=model.get_layer('dense_feature').output)
tsne_data_generator = test_datagen.flow_from_directory(DATASET_PATH,target_size=IMAGE_SIZE,
                                                  batch_size=1,shuffle=False,seed=42,class_mode="binary")
# shuffle

#raise NotImplementedError("Extract features from the tsne_data_generator and fit a t-SNE model for the features,"
#                          "and plot the resulting 2D features of the two classes.")


hidden_features = intermediate_layer_model.predict(tsne_data_generator)
RES_TSNE = TSNE(n_components=2).fit_transform(hidden_features)
Classes = tsne_data_generator.classes
Class1 = np.array( [RES_TSNE[i] for i in range(len(RES_TSNE)) if Classes[i] == 0] )
Class2 = np.array( [RES_TSNE[i] for i in range(len(RES_TSNE)) if Classes[i] == 1] )
plt.scatter(Class1[:, 0], Class1[:, 1], label='COVID-19', c='red')
plt.scatter(Class2[:, 0], Class2[:, 1], label='Normal', c='blue')
plt.legend()
# Out:
# Found 130 images belonging to 2 classes.

# %% [markdown]
# <!-- ## Task 2: COVID-19 vs Normal vs Tertiary Pneumonia (Bacterial and Viral) -->

# %% [markdown]
# <!-- #### Renew Training Batch and Validation Batch -->

# %% [markdown]
# <!-- #### Renew Model -->
